# %%
using Plots

x = 1:10
y = x.^2

scatter(x, y, label="Pontos", xlabel="x", ylabel="y", title="Gráfico de Dispersão")

# %%
bar(["A", "B", "C"], [10, 20, 30], label="Valores", title="Gráfico de Barras")

# %%
p1 = plot(x, y, title="Gráfico 1")
p2 = scatter(x, y, title="Gráfico 2")
plot(p1, p2, layout=(2,1))
